# %% [markdown]
# # Set up Traffic Generator Code

# %%
import binascii
import random
import struct
import numpy as np
import os

from itertools import izip

PACKET_HEADER_FMT = "<II4BIi"
PACKET_HEADER_LEN = struct.calcsize(PACKET_HEADER_FMT)

FRAME_HEADER_FMT = "<II"
FRAME_HEADER_LEN = struct.calcsize(FRAME_HEADER_FMT)



def make_random_packet(preamble, sync, payload_len, counter):
    '''
    preamble and sync are expected to be bytearray or bytes objects
    
    payload len should not exceed 255
    '''
    
    if (payload_len > 255-PACKET_HEADER_LEN) or (payload_len < 0):
        # payload len is an 8 bit field so cannot be larger than 255
        raise ValueError("Payload len must be >=0 and < {}".format(256-PACKET_HEADER_LEN))
    
    # counter takes up 2 bytes
    payload = os.urandom(payload_len-2)
    
    packet_len = len(payload) + PACKET_HEADER_LEN
    
    # assemble fields to compute CRC32
    packed_fields = struct.pack(PACKET_HEADER_FMT, preamble,
                                                   sync,
                                                   packet_len, packet_len, 
                                                   packet_len, packet_len,
                                                   counter,
                                                   0)
    
    # only compute CRC for fields up to the crc itself
    crc = binascii.crc32(packed_fields[:-4])
    
    # now insert CRC
    packed_fields = struct.pack(PACKET_HEADER_FMT, preamble,
                                                   sync,
                                                   packet_len, packet_len, 
                                                   packet_len, packet_len,
                                                   counter,
                                                   crc)
    
    
    return packed_fields + payload


def make_frame(pre_spacing, packet):
    '''
    rework this to remove need for frame_count, num bursts, bytes_per_sym
    '''
    
    frame_len = len(packet) + FRAME_HEADER_LEN
    
    frame_header = struct.pack(FRAME_HEADER_FMT, 
                               pre_spacing,
                               frame_len)

    
    return frame_header + packet


def make_random_data_file(preamble, sync, max_spacing, num_bits, truth_name, out_name):
    
    # setup constants
    syms_per_byte = 4
    samps_per_sym = 4
    
    samps_per_byte = samps_per_sym*syms_per_byte
    generated_bits = 0
    packet_sizes = []
    while generated_bits < num_bits:
        packet_size = np.random.randint(low=2,high=256/4-PACKET_HEADER_LEN, size=1)[0]
        packet_sizes.append(packet_size)
        generated_bits += packet_size*8

    num_packets = len(packet_sizes)
    print("generating {} bits in {} packets".format(sum(packet_sizes)*8, num_packets))
    
    pre_spacing = np.random.randint(low=samps_per_byte*160,high=max_spacing, size=(num_packets,))
    #post_spacing = np.random.randint(low=1,high=max_spacing, size=(num_packets,))
    
    

    #pre_spacing = [80,]*len(packet_sizes)
    #packet_sizes = [24,]*len(packet_sizes)
    # make all the packets 
    packets = [ make_random_packet(preamble, sync, packet_sizes[i], i) for i in range(num_packets)]
    

    
    # write out the packets as ground truth
    with open(truth_name, 'wb') as f:
        for p in packets:
            f.write(p)
            
    
    # encapsulate packets in frames and write to disk
    with open(out_name, 'wb') as f:
        for pre, packet in izip(pre_spacing, packets):
            frame = make_frame(pre, packet)
            f.write(frame)

# %% [markdown]
# # Configure traffic generator and write file to disk

# %%
preamble = 0x99999999
sync = 0x1DFCCF1A
max_spacing = 256*8*2
num_bits = 1e6

truth_name = "/home/cpomeroy/Projects/DARPA/hurdle1/truth_packets.bin"
out_name = "/home/cpomeroy/Projects/DARPA/hurdle1/py_packets.bin"

make_random_data_file(preamble, sync, max_spacing, num_bits, truth_name, out_name)
# Out:
# generating 1000152 bits in 5570 packets

# %% [markdown]
# # Generate IQ Samples

# %%
from matlab.hurdle_1 import hurdle_1
tb = hurdle_1()
tb.start()
tb.wait()

# %% [markdown]
# # Set up code to parse decoded packets

# %%
def parse_packets(preamble, sync, packet_bytes):
    sync_header = struct.pack("<II", preamble, sync)
    
    packets = []
    pos = packet_bytes.find(sync_header)
    
    while pos>=0:
        
        next_pos = packet_bytes.find(sync_header, pos+1)
        
        if next_pos > 0:
            packets.append(packet_bytes[pos:next_pos])
        else:
            packets.append(packet_bytes[pos:])
                
        pos = next_pos
    
    
    return packets


# read in truth packets, whole file
with open(truth_name, 'rb') as f:
    truth_bytes = f.read()

# read in decoded file, whole file
decoded_name = '/home/cpomeroy/Projects/DARPA/hurdle1/matlab/decoded.bin'
with open(decoded_name, 'rb') as f:
    decoded_bytes = f.read()

truth_packets =  parse_packets(preamble, sync, truth_bytes)     
decoded_packets =  parse_packets(preamble, sync, decoded_bytes)

# %% [markdown]
# # Do Naive Implementation of BER first

# %%
from collections import namedtuple

# test for sane packet lengths


truth_packet_counters = [struct.unpack("<I",p[12:16])[0] for p in truth_packets]
truth_packet_crcs = [struct.unpack("<i",p[16:20])[0] for p in truth_packets]
decoded_packet_counters =  [struct.unpack("<I",p[12:16])[0] for p in decoded_packets]
decoded_packet_crcs =  [struct.unpack("<i",p[16:20])[0] for p in decoded_packets]
#print(decoded_packet_counters)


correct_count = 0

for i, c in enumerate(decoded_packet_counters):
    # try to match each decoded packet counter c against a truth packet counter t
    matched_ind = next( (i for i,t in enumerate(truth_packet_counters) if t == c), -1)
    
    #print(matched_ind)
    if matched_ind >= 0:
        t_crc = truth_packet_crcs[matched_ind]
        d_crc = decoded_packet_crcs[i]
        
        # check that CRCs match
        
        if t_crc == d_crc:
        
            tp = bytearray(truth_packets[matched_ind])
            dp = bytearray(decoded_packets[i])

            tp = tp[:-8]
            dp = dp[:-8]
            
            bit_errors = sum([bin(a^b).count("1") for a,b in izip(tp, dp)])
            bits_correct = 8*len(tp)-bit_errors
            
            if bit_errors > 0:
                print("Packet found with {} bit errors. Bits correct was {}".format(bit_errors, bits_correct))
                print("truth:  ",binascii.hexlify(tp))
                print("decoded:",binascii.hexlify(dp))
            else:
                print("packet correct")
        else:
            print("crc fail")
            
    else:
        bit_errors = 8*len(decoded_packets[i])
        bits_correct = 0
        print("No packet found, adding {} bit errors".format(bit_errors))
        
    correct_count += bits_correct
        
bit_count = 8*sum(len(t) for t in truth_packets)        
print("found {} packets out of total {}".format(len(decoded_packets), len(truth_packets)))
ber = (bit_count-correct_count)/float(bit_count)
print("Bit error rate was {}, correct bits: {} total bits {}".format(ber, correct_count, bit_count))
# Out:
# crc fail
# packet correct
# No packet found, adding 208 bit errors
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# Packet found with 15 bit errors. Bits correct was 257
# ('truth:  ', '999999991acffc1d2a2a2a2a09000000b81956ff615ff912a1b82ce68bf5d48d921a')
# ('decoded:', '999999991acffc1d2a2a2a2a09000000b81956ff615ff912a1982e6689f4c4ccdb8f')
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# crc fail
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# Packet found with 7 bit errors. Bits correct was 265
# ('truth:  ', '999999991acffc1d2a2a2a2a1a000000c9e1fabd3026c2cae1bf8300f99396d507e3')
# ('decoded:', '999999991acffc1d2a2a2a2a1a000000c9e1fabd3026c2cae1bf8300d99996c52773')
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# No packet found, adding 272 bit errors
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# Packet found with 5 bit errors. Bits correct was 283
# ('truth:  ', '999999991acffc1d2c2c2c2c31000000f6e36f36f2cc9536d840fdf130bd2cf4875b79b1')
# ('decoded:', '999999991acffc1d2c2c2c2c31000000f6e36f36f2cc9536d840fdf130bd2cf487537333')
# packet correct
# packet correct
# No packet found, adding 184 bit errors
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# Packet found with 5 bit errors. Bits correct was 211
# ('truth:  ', '999999991acffc1d23232323400000004e6382b9ee8b6fc0c0dccd')
# ('decoded:', '999999991acffc1d23232323400000004e6382b9ee8b67c0c8cc4c')
# Packet found with 3 bit errors. Bits correct was 309
# ('truth:  ', '999999991acffc1d2f2f2f2f410000006a560323d3bfeb6fb035b8df42a650cb414ba0de31ed86')
# ('decoded:', '999999991acffc1d2f2f2f2f410000006a560323d3bfeb6fb035b8df42a650cb414ba0de31cd8c')
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# Packet found with 4 bit errors. Bits correct was 228
# ('truth:  ', '999999991acffc1d25252525560000000d4156306b89b3b76b2b46b2a3')
# ('decoded:', '999999991acffc1d25252525560000000d4156306b89b3b76b3b66b3b3')
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# crc fail
# packet correct
# Packet found with 5 bit errors. Bits correct was 195
# ('truth:  ', '999999991acffc1d2121212166000000937769de1737627891')
# ('decoded:', '999999991acffc1d2121212166000000937769de17366679b3')
# Packet found with 8 bit errors. Bits correct was 304
# ('truth:  ', '999999991acffc1d2f2f2f2f6700000088a65aa606fe624a1c478e57e54ab0b35241f50505fc48')
# ('decoded:', '999999991acffc1d2f2f2f2f6700000088a65aa606fe624a1c478e57e54ab0b31241f10504d66c')
# packet correct
# crc fail
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# No packet found, adding 208 bit errors
# packet correct
# packet correct
# Packet found with 3 bit errors. Bits correct was 165
# ('truth:  ', '999999991acffc1d1d1d1d1d7c0000002ddb054bca')
# ('decoded:', '999999991acffc1d1d1d1d1d7c0000002ddb054b98')
# packet correct
# packet correct
# crc fail
# Packet found with 1 bit errors. Bits correct was 311
# ('truth:  ', '999999991acffc1d2f2f2f2f810000006cb84e55bea9b562065ff36a1a5cde58b2d5e37519778d')
# ('decoded:', '999999991acffc1d2f2f2f2f810000006cb84e55bea9b562065ff36a1a5cde58b2d5e375197789')
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# No packet found, adding 224 bit errors
# packet correct
# Packet found with 1 bit errors. Bits correct was 207
# ('truth:  ', '999999991acffc1d222222228a000000139c933cf0b6153b278b')
# ('decoded:', '999999991acffc1d222222228a000000139c933cf0b61533278b6deb50bd246459d6195b9b9b9b8fde1e1e1d15a2d2090000139c933cf0b6')
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# Packet found with 4 bit errors. Bits correct was 220
# ('truth:  ', '999999991acffc1d24242424910000008d662d47f66e8e1302637484')
# ('decoded:', '999999991acffc1d24242424910000008d662d47f66e8e130266648c')
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# Packet found with 14 bit errors. Bits correct was 218
# ('truth:  ', '999999991acffc1d25252525a500000044f885a413aa47731e400f11c1')
# ('decoded:', '999999991acffc1d25252525a500000044f885a413aa46733cc45b33978a3810aeb0bc68cb8d5b4b4b4b437d1e2602a6a6a6a9278700f885a413aa46733cc45b33978a')
# Packet found with 4 bit errors. Bits correct was 364
# ('truth:  ', '999999991acffc1d36363636a7000000331d8c08bfd601a1bc61260b7116f53d25d671dc278c48013813168e4100')
# ('decoded:', '999999991acffc1d36363636a7000000331d8c08bfd601a1bc61260b7116f53d25d671dc278cc8013813368c4110')
# packet correct
# Packet found with 12 bit errors. Bits correct was 316
# ('truth:  ', '999999991acffc1d31313131a90000003fb114881cd2b4402d435fcce3965f98443ec8ce317b605b77')
# ('decoded:', '999999991acffc1d31313131a90000003fb114881cd2b4402d435fcce3965f98c43cc8ce337264f266')
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# Packet found with 1 bit errors. Bits correct was 191
# ('truth:  ', '999999991acffc1d20202020b200000062a8beeba57ec3aa')
# ('decoded:', '999999991acffc1d20202020b200000062a8beeba57ec3ba')
# Packet found with 1 bit errors. Bits correct was 255
# ('truth:  ', '999999991acffc1d28282828b300000079532b6f5d8a75d2c7d8c7953ca31919')
# ('decoded:', '999999991acffc1d28282828b300000079532b6f5d8a75d2c7d8c7953ca31999')
# crc fail
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# crc fail
# crc fail
# crc fail
# packet correct
# packet correct
# Packet found with 3 bit errors. Bits correct was 213
# ('truth:  ', '999999991acffc1d23232323c2000000fe1dd2fe44f5f6559c4a2d')
# ('decoded:', '999999991acffc1d23232323c2000000fe1dd2fe44f5f6559cca6f')
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# Packet found with 19 bit errors. Bits correct was 245
# ('truth:  ', '999999991acffc1d29292929da000000cf1ae4b554eb427424306666d16b80fa9f')
# ('decoded:', '999999991acffc1d29292929da000000cf1ae4b554eb4276263266664939ca5fcdccb3a06bb4b9d5a424141414126d551d29292929da000000cf1ae4b554eb4276263266664939ca5fcd')
# packet correct
# packet correct
# packet correct
# crc fail
# crc fail
# packet correct
# packet correct
# packet correct
# Packet found with 32 bit errors. Bits correct was 304
# ('truth:  ', '999999991acffc1d32323232e4000000df24399f4d87959ed823093c15b0058c013fb1248ce43889c48f')
# ('decoded:', '999999991acffc1d32323232e4000000df24399f4d87959ed823093c15b004cc099d99b2e6629ccc66e5')
# packet correct
# crc fail
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# Packet found with 4 bit errors. Bits correct was 196
# ('truth:  ', '999999991acffc1d21212121fc0000005376940c6e08f455d4')
# ('decoded:', '999999991acffc1d21212121fc0000005376940c6608f654c4')
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# No packet found, adding 160 bit errors
# No packet found, adding 200 bit errors
# packet correct
# crc fail
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# Packet found with 52 bit errors. Bits correct was 228
# ('truth:  ', '999999991acffc1d2b2b2b2b1e01000096edbbaf5b1c5e3f56c8f18388e850571c54f3')
# ('decoded:', '999999991acffc1d2b2b2b2b1e01000096edbbaf7319de6afc99a7161181f5fe79fda6')
# Packet found with 4 bit errors. Bits correct was 212
# ('truth:  ', '999999991acffc1d232323231f0100008d162e2bc047a297a165c9')
# ('decoded:', '999999991acffc1d232323231f0100008d162e2bc047a297b164cc')
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# crc fail
# packet correct
# crc fail
# Packet found with 3 bit errors. Bits correct was 261
# ('truth:  ', '999999991acffc1d292929292d010000e65e97af7e918b7211f9ce7afbf58904be')
# ('decoded:', '999999991acffc1d292929292d010000e65e97af7e918b7211f9ce7afbf58984f6')
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# No packet found, adding 208 bit errors
# packet correct
# packet correct
# packet correct
# packet correct
# Packet found with 2 bit errors. Bits correct was 366
# ('truth:  ', '999999991acffc1d363636363f0100004fbeba7110d94050ed0a11af328eccc1752df01450709d600116490d4352')
# ('decoded:', '999999991acffc1d363636363f0100004fbeba7110d94050ed0a11af328eccc1752df01450709d600116490d4376')
# Packet found with 7 bit errors. Bits correct was 337
# ('truth:  ', '999999991acffc1d3333333340010000853113c018752ad5975df6509799590238edcb4068eae0a784c1bb')
# ('decoded:', '999999991acffc1d3333333340010000853113c018752ad5975df6509799590238cdcb4068cae0a78cc332')
# Packet found with 4 bit errors. Bits correct was 236
# ('truth:  ', '999999991acffc1d26262626410100001c510982831f87944fe8db60a953')
# ('decoded:', '999999991acffc1d26262626410100001c510982831f87944fecdb60a919')
# Packet found with 18 bit errors. Bits correct was 222
# ('truth:  ', '999999991acffc1d2626262642010000f2febc9072b4ad73b162b87f1d69')
# ('decoded:', '999999991acffc1d2626262642010000f2febc9072b48d73336631ea3bc3')
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# Packet found with 6 bit errors. Bits correct was 322
# ('truth:  ', '999999991acffc1d3131313159010000afcdb00f9056975ac16027e446d80d55a16cbc9039e58168b1')
# ('decoded:', '999999991acffc1d3131313159010000afcdb00f9056975ac16027e446d80d55a16cbc9099e5896c99')
# Packet found with 1 bit errors. Bits correct was 327
# ('truth:  ', '999999991acffc1d313131315a0100004162051dc142123701d9a2b41c9f99928b3c2d9309658bb236')
# ('decoded:', '999999991acffc1d313131315a0100004162051dc142123701d9a2b41c9f99928b3c2d9309659bb236')
# crc fail
# crc fail
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# No packet found, adding 352 bit errors
# packet correct
# crc fail
# crc fail
# packet correct
# packet correct
# packet correct
# crc fail
# Packet found with 16 bit errors. Bits correct was 320
# ('truth:  ', '999999991acffc1d323232327f0100004d28baf4c7e0251a3f5c3943593424a4a2439f7e5a273942499a')
# ('decoded:', '999999991acffc1d323232327f0100004d28baf4c7e0251a3f5c3943593424a4a6439b6e5a663344db30')
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# Packet found with 4 bit errors. Bits correct was 228
# ('truth:  ', '999999991acffc1d2525252586010000a392c017aa11d9945a17862027')
# ('decoded:', '999999991acffc1d2525252586010000a392c017aa11d9945a17863233')
# packet correct
# No packet found, adding 208 bit errors
# packet correct
# packet correct
# packet correct
# Packet found with 3 bit errors. Bits correct was 197
# ('truth:  ', '999999991acffc1d212121218c010000f8bc6966cefe94cb26')
# ('decoded:', '999999991acffc1d212121218c010000f8bc6966cefe94cb33')
# packet correct
# packet correct
# packet correct
# Packet found with 1 bit errors. Bits correct was 423
# ('truth:  ', '999999991acffc1d3d3d3d3d90010000623ec826596ca7273fdee31d57160787ca030eb5267143960c1fd8e2868e53fd60c7d616e8')
# ('decoded:', '999999991acffc1d3d3d3d3d90010000623ec826596ca7273fdee31d57160787ca030eb5267143960c1fd8e2868e53fd60c7d616c8')
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# Packet found with 2 bit errors. Bits correct was 174
# ('truth:  ', '999999991acffc1d1e1e1e1e9e010000a92de248468e')
# ('decoded:', '999999991acffc1d1e1e1e1e9e010000a92de248c48e')
# packet correct
# packet correct
# packet correct
# Packet found with 21 bit errors. Bits correct was 219
# ('truth:  ', '999999991acffc1d26262626a2010000cabfc34687fb11242425adc208d4')
# ('decoded:', '999999991acffc1d26262626a2010000cabfc34687fb99262630ec6bae42')
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# No packet found, adding 200 bit errors
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# No packet found, adding 176 bit errors
# packet correct
# packet correct
# packet correct
# Packet found with 1 bit errors. Bits correct was 183
# ('truth:  ', '999999991acffc1d1f1f1f1fe6010000e554887a99a8c8')
# ('decoded:', '999999991acffc1d1f1f1f1fe6010000e554887a99a8c9')
# No packet found, adding 176 bit errors
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# No packet found, adding 224 bit errors
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# Packet found with 1 bit errors. Bits correct was 247
# ('truth:  ', '999999991acffc1d272727271302000053d9aa7dc837d7e32269554a62c087')
# ('decoded:', '999999991acffc1d272727271302000053d9aa7dc837d7e32269554a66c087')
# packet correct
# packet correct
# Packet found with 1 bit errors. Bits correct was 327
# ('truth:  ', '999999991acffc1d31313131160200009d3b81ce86e87906cf5441f0ee14defdb5e72784552859552e')
# ('decoded:', '999999991acffc1d31313131160200009d3b81ce86e87906cf5441f0ee14defdb5e727845528595526')
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# No packet found, adding 216 bit errors
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# Packet found with 7 bit errors. Bits correct was 193
# ('truth:  ', '999999991acffc1d212121213b02000082748ae436805b3d3a')
# ('decoded:', '999999991acffc1d212121213b02000082748ae47680733b30')
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# Packet found with 5 bit errors. Bits correct was 187
# ('truth:  ', '999999991acffc1d202020204502000012528bf3e5128839')
# ('decoded:', '999999991acffc1d202020204502000012528bf3e5329933')
# packet correct
# Packet found with 23 bit errors. Bits correct was 241
# ('truth:  ', '999999991acffc1d2929292947020000d8f74af9a7c97c58b79c1c30176b2b3a2c')
# ('decoded:', '999999991acffc1d2929292947020000d8f74af9a7c97c48b39c8c9a9339b99bb6')
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# crc fail
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# Packet found with 2 bit errors. Bits correct was 286
# ('truth:  ', '999999991acffc1d2c2c2c2c650200006daf84717c9a4e2b301623faf294576871c2bb93')
# ('decoded:', '999999991acffc1d2c2c2c2c650200006daf84717c9a4e2b301623faf294576871c2b99b')
# packet correct
# packet correct
# packet correct
# packet correct
# Packet found with 7 bit errors. Bits correct was 265
# ('truth:  ', '999999991acffc1d2a2a2a2a6a0200003b9541d5a054e9aa0abed674879bf80ab5be')
# ('decoded:', '999999991acffc1d2a2a2a2a6a0200003b9541d5a054e9aa0abed6748799d88a9196')
# packet correct
# packet correct
# No packet found, adding 208 bit errors
# crc fail
# packet correct
# Packet found with 1 bit errors. Bits correct was 311
# ('truth:  ', '999999991acffc1d2f2f2f2f70020000c01d106899dd6db6aa418981b4de954146fde9caf8d4c9')
# ('decoded:', '999999991acffc1d2f2f2f2f70020000c01d106899dd6db6aa418981b4de954146fde9caf8dcc9')
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# Packet found with 1 bit errors. Bits correct was 319
# ('truth:  ', '999999991acffc1d3030303086020000062b20ef9adb41eae32925812eea59f72268a6affd0d48af')
# ('decoded:', '999999991acffc1d3030303086020000062b20ef9adb41eae32925812eea59f72268a6affd0dc8af')
# packet correct
# packet correct
# packet correct
# Packet found with 2 bit errors. Bits correct was 326
# ('truth:  ', '999999991acffc1d313131318a020000816517391e5e16a9b4059276ac4085c8841fb684f1de9ac44c')
# ('decoded:', '999999991acffc1d313131318a020000816517391e5e16a9b4059276ac4085c8841fb684f1de9acccc')
# crc fail
# No packet found, adding 160 bit errors
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# crc fail
# No packet found, adding 168 bit errors
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# Packet found with 2 bit errors. Bits correct was 278
# ('truth:  ', '999999991acffc1d2b2b2b2bab02000067ed5187f8d6193efdbb7e0065d3c4e026deed')
# ('decoded:', '999999991acffc1d2b2b2b2bab02000067ed5187f8d6193efdbb7e0065d3c4e026ceec')
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# No packet found, adding 232 bit errors
# packet correct
# packet correct
# packet correct
# packet correct
# No packet found, adding 240 bit errors
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# No packet found, adding 208 bit errors
# Packet found with 2 bit errors. Bits correct was 302
# ('truth:  ', '999999991acffc1d2e2e2e2ec7020000dc9a5474d48ac23a3ba63e0b54886614b40cf94dd205')
# ('decoded:', '999999991acffc1d2e2e2e2ec7020000dc9a5474d48ac23a3ba63e0b54886614b40cf94cd225')
# packet correct
# Packet found with 3 bit errors. Bits correct was 301
# ('truth:  ', '999999991acffc1d2e2e2e2ec9020000efed8b94b725b064557cca706777c54aca93a3533f12')
# ('decoded:', '999999991acffc1d2e2e2e2ec9020000efed8b94b725b064557cca706777c54aca93b3133f13')
# packet correct
# packet correct
# No packet found, adding 184 bit errors
# packet correct
# packet correct
# packet correct
# packet correct
# Packet found with 11 bit errors. Bits correct was 333
# ('truth:  ', '999999991acffc1d33333333d2020000f3a61cd56f78d50ce71d04c63f965e6d4cfe1299618b7ea05f636d')
# ('decoded:', '999999991acffc1d33333333d2020000f3a61cd56f78d50ce71d04c63f965e6d4cfe1299618b36a2473334')
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# Packet found with 3 bit errors. Bits correct was 389
# ('truth:  ', '999999991acffc1d39393939ef020000cefec609a8c6ad5d745145a9c238ed92734a9488828acccf5e945b85feb67dee0d')
# ('decoded:', '999999991acffc1d39393939ef020000cefec609a8c6ad5d745145a9c238ed92734a9488828acccf5e945b85feb67ce60c')
# packet correct
# packet correct
# packet correct
# packet correct
# Packet found with 3 bit errors. Bits correct was 213
# ('truth:  ', '999999991acffc1d23232323f4020000ed6e1628afd9076a8fb544')
# ('decoded:', '999999991acffc1d23232323f4020000ed6e1628afd9066a8fb5cc')
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# Packet found with 8 bit errors. Bits correct was 200
# ('truth:  ', '999999991acffc1d222222220403000042e35333ab741567e50f')
# ('decoded:', '999999991acffc1d222222220403000042e35333ab641566ef5a')
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# No packet found, adding 176 bit errors
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# Packet found with 3 bit errors. Bits correct was 325
# ('truth:  ', '999999991acffc1d313131312f03000081e66042904273f480869616ff25e8d9d70e57792f1e58522b')
# ('decoded:', '999999991acffc1d313131312f03000081e66042904273f480869616ff25e8d9d70e57792f1e585339')
# crc fail
# crc fail
# Packet found with 4 bit errors. Bits correct was 276
# ('truth:  ', '999999991acffc1d2b2b2b2b320300007e29db46317f81fe9277dfb0403e06f81a541a')
# ('decoded:', '999999991acffc1d2b2b2b2b320300007e29db46317f81fe9277dfb0403e26f89a549b')
# Packet found with 2 bit errors. Bits correct was 302
# ('truth:  ', '999999991acffc1d2e2e2e2e330300001b71927cc78d02a853037a756efbfe982e2cd555d42c')
# ('decoded:', '999999991acffc1d2e2e2e2e330300001b71927cc78d02a853037a756efbfe98262cc555d42c')
# packet correct
# packet correct
# packet correct
# packet correct
# No packet found, adding 208 bit errors
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# crc fail
# packet correct
# Packet found with 1 bit errors. Bits correct was 327
# ('truth:  ', '999999991acffc1d313131314a030000b0e1984e4ce1d0fbc21c5b0dee9fb36c6b6a8d2fc441a73a8f')
# ('decoded:', '999999991acffc1d313131314a030000b0e1984e4ce1d0fbc21c5b0dee9fb36c6b6a8d2fc441a33a8f')
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# Packet found with 1 bit errors. Bits correct was 199
# ('truth:  ', '999999991acffc1d2121212151030000d209d3b1cc5b8b1278')
# ('decoded:', '999999991acffc1d2121212151030000d209d3b1cc5b8b3278')
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# Packet found with 10 bit errors. Bits correct was 238
# ('truth:  ', '999999991acffc1d272727276003000016bce205a13c7fb5a1739d43f7af7c')
# ('decoded:', '999999991acffc1d272727276003000016bce205a13c7fb5a1319c4373b736')
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# Packet found with 2 bit errors. Bits correct was 246
# ('truth:  ', '999999991acffc1d272727276d030000cb6488f76ddd4f4afcbbd61c5e9244')
# ('decoded:', '999999991acffc1d272727276d030000cb6488f76ddd4f4afcbbd61cde924c')
# Packet found with 1 bit errors. Bits correct was 239
# ('truth:  ', '999999991acffc1d262626266e0300001a3adc7975832514bbc992687605')
# ('decoded:', '999999991acffc1d262626266e0300001a3adc7975832514bbc992687645')
# Packet found with 33 bit errors. Bits correct was 311
# ('truth:  ', '999999991acffc1d333333336f030000835ac63bd580bd19e462cc4ecee1e83576bb0ca480ee71dc57abe0')
# ('decoded:', '999999991acffc1d333333336f030000835ac63bd580bd19e462cccccce1e83766331c8c91cce799fe0285')
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# crc fail
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# Packet found with 1 bit errors. Bits correct was 311
# ('truth:  ', '999999991acffc1d2f2f2f2f960300001369c69ab3bf6c79b1189ba780d94f48fd0597c4721895')
# ('decoded:', '999999991acffc1d2f2f2f2f960300001369c69ab3bf6c79b1189ba780d94f48fd0597c4721995')
# crc fail
# crc fail
# packet correct
# Packet found with 1 bit errors. Bits correct was 343
# ('truth:  ', '999999991acffc1d333333339a03000016bc7e8a1f13643685821ace8c93a367876a00f7d97233f079f00d')
# ('decoded:', '999999991acffc1d333333339a03000016bc7e8a1f13643685821ace8c93a367876a00f7d97333f079f00d')
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# Packet found with 3 bit errors. Bits correct was 173
# ('truth:  ', '999999991acffc1d1e1e1e1ea2030000debe9bf17035')
# ('decoded:', '999999991acffc1d1e1e1e1ea2030000debe9bf13030')
# Packet found with 1 bit errors. Bits correct was 351
# ('truth:  ', '999999991acffc1d34343434a303000002d01a67bcddc75d90b8522e6bea10001636ffb5fa3d769c2d227669')
# ('decoded:', '999999991acffc1d34343434a303000002d01a67bcddc75d90b8522e6bea10001636ffb5fa3d769c2d226669')
# packet correct
# Packet found with 2 bit errors. Bits correct was 198
# ('truth:  ', '999999991acffc1d21212121a6030000cc2762aa7276fad3bf')
# ('decoded:', '999999991acffc1d21212121a6030000cc2762aa7266fad33f')
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# Packet found with 2 bit errors. Bits correct was 270
# ('truth:  ', '999999991acffc1d2a2a2a2aad030000b329193fc82d42d61753ad957b9b7fc718d1')
# ('decoded:', '999999991acffc1d2a2a2a2aad030000b329193fc82d42d61753ad957b9b7fc71991')
# Packet found with 3 bit errors. Bits correct was 333
# ('truth:  ', '999999991acffc1d32323232ae030000df22d669e3a2fee0773346dcb27a3734056a31910bfc499fb7af')
# ('decoded:', '999999991acffc1d32323232ae030000df22d669e3a2fee0773346dcb27a3734056a31990bfc499db3af')
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# No packet found, adding 192 bit errors
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# crc fail
# packet correct
# crc fail
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# crc fail
# crc fail
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# Packet found with 13 bit errors. Bits correct was 355
# ('truth:  ', '999999991acffc1d36363636e2030000650b00a6bfc5e5852a6f96d54c93c76f2336c0d05e740be98cbbebfd9e12')
# ('decoded:', '999999991acffc1d36363636e2030000650b00a6bfc5e5852a6f96d54c93c76f2336c0d05e640be999b3abb99a74')
# No packet found, adding 192 bit errors
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# crc fail
# crc fail
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# Packet found with 32 bit errors. Bits correct was 216
# ('truth:  ', '999999991acffc1d27272727060400004c02e01e05a85e58880d328fd96f6e')
# ('decoded:', '999999991acffc1d27272727060400004c02e01e05ac464ccea49be54c3537')
# packet correct
# packet correct
# crc fail
# packet correct
# crc fail
# crc fail
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# crc fail
# packet correct
# crc fail
# packet correct
# crc fail
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# Packet found with 2 bit errors. Bits correct was 246
# ('truth:  ', '999999991acffc1d272727271d040000d2d2f899b507e97fc4be0ec3189d7a')
# ('decoded:', '999999991acffc1d272727271d040000d2d2f899b507e97fc4be0ec318cd7a')
# packet correct
# packet correct
# packet correct
# Packet found with 20 bit errors. Bits correct was 268
# ('truth:  ', '999999991acffc1d2c2c2c2c21040000b51c7f619de2b36cca7cd351e8ec63a4a771d227')
# ('decoded:', '999999991acffc1d2c2c2c2c21040000b51c7f619de2b36cca7cd311ece673b6f318cb31')
# packet correct
# Packet found with 1 bit errors. Bits correct was 335
# ('truth:  ', '999999991acffc1d3232323223040000bc5aaa73f05264919e6375eac26d83c10a8d71b137410fcdbfac')
# ('decoded:', '999999991acffc1d3232323223040000bc5aaa73f05264919e6375eac26d83c10a8d71b137410fcd9fac')
# packet correct
# Packet found with 18 bit errors. Bits correct was 406
# ('truth:  ', '999999991acffc1d3d3d3d3d250400002142af0af15cdfe85a060cd00cd9b0150a8f67ded247f174183b9ab9495794428c5d19bd50')
# ('decoded:', '999999991acffc1d3d3d3d3d250400002142af0af15cdfe85a060cd00cd9b0150a8f67ded247f17418339ab959579cc48cd9333bf5')
# crc fail
# crc fail
# Packet found with 10 bit errors. Bits correct was 318
# ('truth:  ', '999999991acffc1d3131313128040000bdc8f8da03474cb1c418b659f49a833afaba6e3614da403294')
# ('decoded:', '999999991acffc1d3131313128040000bdc8f8da03474cb1c418b659f49a833afaba663314ce623386')
# packet correct
# Packet found with 2 bit errors. Bits correct was 230
# ('truth:  ', '999999991acffc1d252525252a040000f5f6b6168c9cdd839c606e28f5')
# ('decoded:', '999999991acffc1d252525252a040000f5f6b6168c9cdd839c626628f5')
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# No packet found, adding 216 bit errors
# packet correct
# packet correct
# packet correct
# No packet found, adding 200 bit errors
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# Packet found with 2 bit errors. Bits correct was 246
# ('truth:  ', '999999991acffc1d272727273e04000002d27f2b3b73292ab26085e047a801')
# ('decoded:', '999999991acffc1d272727273e04000002d27f2b3b73292ab26085e047a813')
# packet correct
# Packet found with 3 bit errors. Bits correct was 333
# ('truth:  ', '999999991acffc1d32323232400400005102395a63fd6f2c840f81a26a16df079b74f133cdd23d45bf7a')
# ('decoded:', '999999991acffc1d32323232400400005102395a63fd6f2c840f81a26a16df079b74f133ccd33d45bf3a')
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# Packet found with 1 bit errors. Bits correct was 167
# ('truth:  ', '999999991acffc1d1d1d1d1d500400007763e8a6f2')
# ('decoded:', '...')
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# Packet found with 2 bit errors. Bits correct was 262
# ('truth:  ', '999999991acffc1d2929292959040000c6ab014d4af9e28100adb16f51d7730047')
# ('decoded:', '999999991acffc1d2929292959040000c6ab014d4af9e28100adb16f51d7330067')
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# crc fail
# crc fail
# crc fail
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# No packet found, adding 160 bit errors
# Packet found with 1 bit errors. Bits correct was 271
# ('truth:  ', '999999991acffc1d2a2a2a2a780400009d76dc2bbf59e491b67544b5172f70959cdf')
# ('decoded:', '999999991acffc1d2a2a2a2a780400009d76dc2bbf59e491b67544b5172f70959ccf')
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# Packet found with 4 bit errors. Bits correct was 324
# ('truth:  ', '999999991acffc1d31313131850400006509f965cfccd76bb36f60e5b25dc3b03d94663cb3a17841f3')
# ('decoded:', '999999991acffc1d31313131850400006509f965cfccd76bb36f60e5b25dc3b03d94663cb3b13841db')
# crc fail
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# No packet found, adding 216 bit errors
# packet correct
# crc fail
# Packet found with 24 bit errors. Bits correct was 272
# ('truth:  ', '999999991acffc1d2d2d2d2d9104000010a3ece03a267860db5e221716a9164e6ee6478040')
# ('decoded:', '999999991acffc1d2d2d2d2d9104000010a3ece03a267860db5e223736ab34ccccccce15d5')
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# No packet found, adding 208 bit errors
# Packet found with 48 bit errors. Bits correct was 264
# ('truth:  ', '999999991acffc1d2f2f2f2f98040000a508567f51dd686cf2c91762b7c29d58e0bc203ffac674')
# ('decoded:', '999999991acffc1d2f2f2f2f98040000a508567f51dd686cf2cd9333916bcc0e7ad6ba955f6312')
# packet correct
# packet correct
# No packet found, adding 200 bit errors
# packet correct
# Packet found with 12 bit errors. Bits correct was 284
# ('truth:  ', '999999991acffc1d2d2d2d2d9d040000a81c3aaad19a50ef282d32ec909f5586f936ee3ee3')
# ('decoded:', '999999991acffc1d2d2d2d2d9d040000a81c3aaad19a50ef282d32ec919f558ef334ce6cc6')
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# crc fail
# Packet found with 1 bit errors. Bits correct was 311
# ('truth:  ', '999999991acffc1d2f2f2f2fb6040000a8d0bb3f134db29ab7581d81c4290ed9b733148c157764')
# ('decoded:', '999999991acffc1d2f2f2f2fb6040000a8d0bb3f134db29ab7581d81c4290ed9b733148c157664')
# crc fail
# packet correct
# packet correct
# Packet found with 5 bit errors. Bits correct was 251
# ('truth:  ', '999999991acffc1d28282828ba0400002fb42a158772d47171fb943790d91220')
# ('decoded:', '999999991acffc1d28282828ba0400002fb42a158772d47171fb943398d99330')
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# crc fail
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# Packet found with 9 bit errors. Bits correct was 191
# ('truth:  ', '999999991acffc1d21212121ce040000a5eebf51d614c0e6cb')
# ('decoded:', '999999991acffc1d21212121ce040000a5eebf51d65cc4ccd2')
# packet correct
# Packet found with 1 bit errors. Bits correct was 319
# ('truth:  ', '999999991acffc1d30303030d0040000ca07cb05e628eea133ed0fa31df222bae00138a80339b8ce')
# ('decoded:', '999999991acffc1d30303030d0040000ca07cb05e628eea133ed0fa31df222bae00138a8033998ce')
# Packet found with 3 bit errors. Bits correct was 205
# ('truth:  ', '999999991acffc1d22222222d10400006cbc96275bab2ffe7b9c')
# ('decoded:', '999999991acffc1d22222222d10400006cbc96275bab2ffe7399')
# packet correct
# crc fail
# crc fail
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# No packet found, adding 232 bit errors
# packet correct
# Packet found with 5 bit errors. Bits correct was 179
# ('truth:  ', '999999991acffc1d1f1f1f1fe70400006bf1ffc437553c')
# ('decoded:', '999999991acffc1d1f1f1f1fe70400006bf1ffc433119c')
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# Packet found with 1 bit errors. Bits correct was 271
# ('truth:  ', '999999991acffc1d2a2a2a2af7040000f0d0e69edfe65f2f51fa6f757058cd617fb0')
# ('decoded:', '999999991acffc1d2a2a2a2af7040000f0d0e69edfe65f2f51fa6f757058cd617f30')
# packet correct
# packet correct
# packet correct
# crc fail
# Packet found with 1 bit errors. Bits correct was 223
# ('truth:  ', '999999991acffc1d24242424fc0400008fe168893f99e168dc9e2e62')
# ('decoded:', '999999991acffc1d24242424fc0400008fe168893f99e168dc9e2662')
# Packet found with 5 bit errors. Bits correct was 363
# ('truth:  ', '999999991acffc1d36363636fd040000295a35ab39cf51eafc3d847e92ba92368dc2f0736a74b4eda8840aeafca9')
# ('decoded:', '999999991acffc1d36363636fd040000295a35ab39cf51eafc3d847e92ba92368dc2f0736a74b4eda8c40e6efce9')
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# Packet found with 1 bit errors. Bits correct was 303
# ('truth:  ', '999999991acffc1d2e2e2e2e060500003a05eabf70151b8f9d3d4d4f538ef8eca8524dc30071')
# ('decoded:', '999999991acffc1d2e2e2e2e060500003a05eabf70151b8f9d3d4d4f538ef8eca8524cc30071')
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# Packet found with 45 bit errors. Bits correct was 275
# ('truth:  ', '999999991acffc1d303030300e05000057a382c25d054b6d42cf74c9cf5077db9caa5d781b0e4792')
# ('decoded:', '999999991acffc1d303030300e05000057a382c25d054b6d42cf76ccc71a314dceff041e8da721cb')
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# Packet found with 9 bit errors. Bits correct was 351
# ('truth:  ', '999999991acffc1d353535351905000071f3b98d4ce2e80d4a09c9c25ae67079342a1c038e7bfce4b11fe24d9a')
# ('decoded:', '999999991acffc1d353535351905000071f3b98d4ce2e80d4a09c9c25ae67079342a1c038e73fcccb31be6c998')
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# Packet found with 1 bit errors. Bits correct was 183
# ('truth:  ', '999999991acffc1d1f1f1f1f24050000b4dac5a15c6487')
# ('decoded:', '999999991acffc1d1f1f1f1f24050000b4dac5a15c64c7')
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# Packet found with 5 bit errors. Bits correct was 283
# ('truth:  ', '999999991acffc1d2c2c2c2c2c0500005faed792a0e283f920d9a39e3de93f8e20bfab0e')
# ('decoded:', '999999991acffc1d2c2c2c2c2c0500005faed792a0e283f920d9a39e3de93f8e209fb926')
# Packet found with 5 bit errors. Bits correct was 395
# ('truth:  ', '999999991acffc1d3a3a3a3a2d050000c6db9eaed8a86ff0364803dc2384bc79db363b92f8088b8ebf108bd9601c5ffe4fe7')
# ('decoded:', '999999991acffc1d3a3a3a3a2d050000c6db9eaed8a86ff0364803dc2384bc79db363b92f8088b8ebf1089d9601c5ff66767')
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# Packet found with 4 bit errors. Bits correct was 228
# ('truth:  ', '999999991acffc1d252525253a0500005dcb6d47cd0b740b46e7d9b304')
# ('decoded:', '999999991acffc1d252525253a0500005dcb6d47cd0b740b4667d99326')
# crc fail
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# No packet found, adding 176 bit errors
# crc fail
# packet correct
# packet correct
# No packet found, adding 192 bit errors
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# Packet found with 4 bit errors. Bits correct was 284
# ('truth:  ', '999999991acffc1d2c2c2c2c510500001ed6820b04aa9cf1ae730dcc5505e24fd1565c71')
# ('decoded:', '999999991acffc1d2c2c2c2c510500001ed6820b04aa9cf1ae730ccc5505e24fd9564471')
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# Packet found with 19 bit errors. Bits correct was 237
# ('truth:  ', '999999991acffc1d28282828680500000aafb5987c83cccfe04a219ef8788b9a')
# ('decoded:', '999999991acffc1d28282828680500000aafb5987c83cccfe4ca6398a1f19330')
# packet correct
# crc fail
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# Packet found with 17 bit errors. Bits correct was 343
# ('truth:  ', '999999991acffc1d353535357c05000040f441812c17399e4b82c023c1e6017415c4b042e13d1c450be5cca6c1')
# ('decoded:', '999999991acffc1d353535357c05000040f441812c17399e4b82c023c1e6017415c4b062611d8c6589644ee668')
# packet correct
# packet correct
# No packet found, adding 208 bit errors
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# Packet found with 1 bit errors. Bits correct was 199
# ('truth:  ', '999999991acffc1d212121218605000040f4dd0ebc3e5e1063')
# ('decoded:', '999999991acffc1d212121218605000040f4dd0ebc3e5e1067')
# packet correct
# packet correct
# packet correct
# Packet found with 3 bit errors. Bits correct was 197
# ('truth:  ', '999999991acffc1d212121218a050000f84b0b4428df9d132e')
# ('decoded:', '999999991acffc1d212121218a050000f84b0b4428dd9d9326')
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# Packet found with 2 bit errors. Bits correct was 182
# ('truth:  ', '999999991acffc1d1f1f1f1f97050000c03b02aec25554')
# ('decoded:', '999999991acffc1d1f1f1f1f97050000c03b02aee25544')
# packet correct
# crc fail
# packet correct
# crc fail
# No packet found, adding 168 bit errors
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# crc fail
# No packet found, adding 168 bit errors
# packet correct
# Packet found with 9 bit errors. Bits correct was 327
# ('truth:  ', '999999991acffc1d32323232a60500008276efa8dbaeee40359c2512bdb1e756aa687c1e3da31803b8ac')
# ('decoded:', '999999991acffc1d32323232a60500008276efa8dbaeee40359c2512bdb1e756aa687c1e3db3988998e6')
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# Packet found with 2 bit errors. Bits correct was 190
# ('truth:  ', '999999991acffc1d20202020b105000067c5c0ff9483a993')
# ('decoded:', '999999991acffc1d20202020b105000067c5c0ff9483a999')
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# Packet found with 1 bit errors. Bits correct was 319
# ('truth:  ', '999999991acffc1d30303030b905000074d5274253b9122887dc8d831fe8705691ff71ddc5050db3')
# ('decoded:', '999999991acffc1d30303030b905000074d5274253b9122887dc8d831fe8705691ff71dcc5050db3')
# packet correct
# packet correct
# packet correct
# Packet found with 7 bit errors. Bits correct was 233
# ('truth:  ', '999999991acffc1d26262626bd050000df50b0497363afaea707aa9c8670')
# ('decoded:', '999999991acffc1d26262626bd050000df50b0497363afaea707aacce732')
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# Packet found with 12 bit errors. Bits correct was 204
# ('truth:  ', '999999991acffc1d23232323c305000070b8a5402bf98ef5938362')
# ('decoded:', '999999991acffc1d23232323c305000070b8a5402bf99ce7331664')
# Packet found with 5 bit errors. Bits correct was 267
# ('truth:  ', '999999991acffc1d2a2a2a2ac405000088edba7d53e9ebe8f30877426fd4cce4369a')
# ('decoded:', '999999991acffc1d2a2a2a2ac405000088edba7d53e9ebe8f30877466fdcccc4669a')
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# Packet found with 3 bit errors. Bits correct was 269
# ('truth:  ', '999999991acffc1d2a2a2a2ad1050000254a7d1a0a2118bc26bb0349d066de137b62')
# ('decoded:', '999999991acffc1d2a2a2a2ad1050000254a7d1a0a2118bc26bb0349d066de133b32')
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# Packet found with 1 bit errors. Bits correct was 191
# ('truth:  ', '999999991acffc1d20202020de0500003222859c0e29f73d')
# ('decoded:', '999999991acffc1d20202020de0500003222859c0e29f33d')
# Packet found with 6 bit errors. Bits correct was 362
# ('truth:  ', '999999991acffc1d36363636df050000ab57cca022c0480aa573beec62c22cd7c447d13574557444b45775c7a327')
# ('decoded:', '999999991acffc1d36363636df050000ab57cca022c0480aa573beec62c22cd7c447d13574557644b45734c7b333')
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# Packet found with 9 bit errors. Bits correct was 223
# ('truth:  ', '999999991acffc1d25252525ea050000c472396194f972c75412a16210')
# ('decoded:', '999999991acffc1d25252525ea050000c472396194f972c65432276671')
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# Packet found with 3 bit errors. Bits correct was 261
# ('truth:  ', '999999991acffc1d29292929f40500002900c2f399cec7eb2246449d1d2481d0b3')
# ('decoded:', '999999991acffc1d29292929f40500002900c2f399cec7eb2246449d9d2489d8b3')
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# Packet found with 52 bit errors. Bits correct was 316
# ('truth:  ', '999999991acffc1d3636363609060000b70fb5a1c119b5fd127913d72cfbe4aa82744745d2bd38c442d9d1a26428')
# ('decoded:', '999999991acffc1d3636363609060000b70fb5a1c119b5fd127913d72cfbcc88866ccecdb42b619dd4b3b704cd41')
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# Packet found with 1 bit errors. Bits correct was 263
# ('truth:  ', '999999991acffc1d2929292913060000f1c72cbaedf24e00c1c982ef4674458321')
# ('decoded:', '999999991acffc1d2929292913060000f1c72cbaedf24e00c1c982ef4664458321')
# packet correct
# packet correct
# packet correct
# Packet found with 1 bit errors. Bits correct was 207
# ('truth:  ', '999999991acffc1d2222222217060000d8d934779d148b097664')
# ('decoded:', '999999991acffc1d2222222217060000d8d934779d148b097666')
# packet correct
# ...
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# Packet found with 9 bit errors. Bits correct was 215
# ('truth:  ', '999999991acffc1d242424241c140000c7033143afdc598ed661e4f9')
# ('decoded:', '999999991acffc1d242424241c140000c7033143afdc599cd667ccb3')
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# crc fail
# Packet found with 10 bit errors. Bits correct was 230
# ('truth:  ', '999999991acffc1d26262626261400003dff153e4b2128e5e4ca9202acc8')
# ('decoded:', '999999991acffc1d26262626261400003dff153e4b3128e5e4ce9323e6ce')
# packet correct
# packet correct
# Packet found with 6 bit errors. Bits correct was 346
# ('truth:  ', '999999991acffc1d3434343429140000a83397fc317d875dca5c691d51ec699c2faa290e213c7a03f264f4c5')
# ('decoded:', '999999991acffc1d3434343429140000a83397fc317d875dca5c691d51ec699c2faa290e233c7a03f66ceccd')
# packet correct
# Packet found with 6 bit errors. Bits correct was 322
# ('truth:  ', '999999991acffc1d313131312b14000023c46bd46fc67a3e62ac7bc38b70db91ccd6bb0f461f939152')
# ('decoded:', '999999991acffc1d313131312b14000023c46bd46fc67a3e62ac7bc38b70db91ccd6bb0f661d999953')
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# Packet found with 12 bit errors. Bits correct was 188
# ('truth:  ', '999999991acffc1d212121213514000073dcfe1c711707b63b')
# ('decoded:', '999999991acffc1d212121213514000073dcfe1c719321939d')
# packet correct
# packet correct
# packet correct
# packet correct
# Packet found with 6 bit errors. Bits correct was 290
# ('truth:  ', '999999991acffc1d2d2d2d2d3a140000649ea066356b8a649920964c1bac65cab5a168aab9')
# ('decoded:', '999999991acffc1d2d2d2d2d3a140000649ea066356b8a649920964c1bac65cab1b16ceb99')
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# Packet found with 2 bit errors. Bits correct was 174
# ('truth:  ', '999999991acffc1d1e1e1e1e4014000098828494c9ee')
# ('decoded:', '999999991acffc1d1e1e1e1e4014000098828494cde64bec903885bc857f000155551445d4551e1e1e1e4014000098828494cde6')
# No packet found, adding 176 bit errors
# packet correct
# packet correct
# crc fail
# crc fail
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# No packet found, adding 160 bit errors
# packet correct
# Packet found with 27 bit errors. Bits correct was 285
# ('truth:  ', '999999991acffc1d2f2f2f2f58140000d3453d15081722c1a09af05459b97c55da308d92addd27')
# ('decoded:', '999999991acffc1d2f2f2f2f58140000d3453d15081722c1a09af05459b37cdd9265993409bb4e')
# packet correct
# packet correct
# packet correct
# packet correct
# No packet found, adding 192 bit errors
# packet correct
# Packet found with 7 bit errors. Bits correct was 209
# ('truth:  ', '999999991acffc1d232323235f1400002b2fd7aad19f8caf7ae1b1')
# ('decoded:', '999999991acffc1d232323235f1400002b2fd7aad19b8c8f62e333')
# Packet found with 34 bit errors. Bits correct was 214
# ('truth:  ', '999999991acffc1d2727272760140000e3098b1c09b63418dc645928e2af04')
# ('decoded:', '999999991acffc1d2727272760140000e3098b1c89b3328cc6720cbe7bf5a2')
# Packet found with 2 bit errors. Bits correct was 206
# ('truth:  ', '999999991acffc1d22222222611400008651c226e4b796475c0f')
# ('decoded:', '999999991acffc1d22222222611400008651c226e4b796675c07')
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# Packet found with 7 bit errors. Bits correct was 265
# ('truth:  ', '999999991acffc1d2a2a2a2a681400007282e3679c07a8168ccd2993fc4110f5089d')
# ('decoded:', '999999991acffc1d2a2a2a2a681400007282e3679c07a8168ccd2993fc4198f58ccc')
# Packet found with 1 bit errors. Bits correct was 263
# ('truth:  ', '999999991acffc1d292929296914000017f00ca18c903330803821592b26632f8a')
# ('decoded:', '999999991acffc1d292929296914000017f00ca18c903330803821592b26632f88')
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# Packet found with 2 bit errors. Bits correct was 174
# ('truth:  ', '999999991acffc1d1e1e1e1e72140000b2b2a6cefcb6')
# ('decoded:', '999999991acffc1d1e1e1e1e72140000b2b2a6cefcb3')
# packet correct
# crc fail
# Packet found with 1 bit errors. Bits correct was 199
# ('truth:  ', '999999991acffc1d21212121751400004e84ea8753346d4d6f')
# ('decoded:', '999999991acffc1d21212121751400004e84ea8753346d4c6f')
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# Packet found with 3 bit errors. Bits correct was 285
# ('truth:  ', '999999991acffc1d2c2c2c2c7d140000df0f82fc33f3b1cb816b722d0f85707dcc167c3c')
# ('decoded:', '999999991acffc1d2c2c2c2c7d140000df0f82fc33f3b1cb816b722d0f85707ccc16741c')
# packet correct
# No packet found, adding 192 bit errors
# packet correct
# packet correct
# packet correct
# packet correct
# Packet found with 1 bit errors. Bits correct was 335
# ('truth:  ', '999999991acffc1d323232328414000070d830bfd3c674a0ab40e5cd25784a9b6d718db690c3b1ed4354')
# ('decoded:', '999999991acffc1d323232328414000070d830bfd3c674a0ab40e5cd25784a9b6d718db690c331ed4354')
# packet correct
# packet correct
# crc fail
# packet correct
# Packet found with 2 bit errors. Bits correct was 278
# ('truth:  ', '999999991acffc1d2b2b2b2b8a140000fefa7487594f0d5ed4097d349555644155abe3')
# ('decoded:', '999999991acffc1d2b2b2b2b8a140000fefa7487594f0d5ed4097d349555644155abe6')
# packet correct
# packet correct
# Packet found with 1 bit errors. Bits correct was 287
# ('truth:  ', '999999991acffc1d2c2c2c2c8d1400007819e47a9a1f11de0e6e828a5990a479c2da684b')
# ('decoded:', '999999991acffc1d2c2c2c2c8d1400007819e47a9a1f11de0e6e828a5990a479c2da68cb')
# packet correct
# packet correct
# packet correct
# Packet found with 1 bit errors. Bits correct was 231
# ('truth:  ', '999999991acffc1d25252525911400001e9ce3c09ddebe36a751ba3559')
# ('decoded:', '999999991acffc1d25252525911400001e9ce3c09ddebe36a751bb3559')
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# Packet found with 41 bit errors. Bits correct was 263
# ('truth:  ', '999999991acffc1d2e2e2e2e991400008f3d2d4780efeae6bc1e8390dcdd019da43ad4c4d82e')
# ('decoded:', '999999991acffc1d2e2e2e2e991400008f3d2d4780efeae6bc1c9331999b133b0d60bd9db148')
# packet correct
# packet correct
# packet correct
# crc fail
# Packet found with 11 bit errors. Bits correct was 293
# ('truth:  ', '999999991acffc1d2e2e2e2e9e1400003605fadae4b8b74400463415c2190680004961c34729')
# ('decoded:', '999999991acffc1d2e2e2e2e9e1400003605fadae4b8b74400463415c219068004c965964663')
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# No packet found, adding 184 bit errors
# packet correct
# Packet found with 50 bit errors. Bits correct was 358
# ('truth:  ', '999999991acffc1d3b3b3b3bc61400008725e52e268648737a70d74f211bb3099765b1383347f5b1ce63ea1039efe45b328d06')
# ('decoded:', '999999991acffc1d3b3b3b3bc61400008725e52e268648737a70d74f211b3309966533313246e7318ce6c075638acdf2641b5c')
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# Packet found with 1 bit errors. Bits correct was 295
# ('truth:  ', '999999991acffc1d2d2d2d2dd2140000b3f76b75e658246e084d28bf4021a5bf3a1a2d3d91')
# ('decoded:', '999999991acffc1d2d2d2d2dd2140000b3f76b75e658246e084d28bf4021a5bf3a1a2d3d99')
# packet correct
# Packet found with 1 bit errors. Bits correct was 287
# ('truth:  ', '999999991acffc1d2c2c2c2cd41400005059e1ccd62144fd28d028e0b2c7a93293804464')
# ('decoded:', '999999991acffc1d2c2c2c2cd41400005059e1ccd62144fd28d028e0b2c7a93293804664')
# packet correct
# packet correct
# packet correct
# packet correct
# Packet found with 3 bit errors. Bits correct was 309
# ('truth:  ', '999999991acffc1d2f2f2f2fd91400008d94d840e629e02a76b6405a9c886ac9e8696134c459c3')
# ('decoded:', '999999991acffc1d2f2f2f2fd91400008d94d840e629e02a76b6405a9c886ac9e8696134e45cc3')
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# Packet found with 5 bit errors. Bits correct was 323
# ('truth:  ', '999999991acffc1d31313131e114000041ca9bcdf3087675bf11776860b515fd4ced2dfb28dd7b6238')
# ('decoded:', '999999991acffc1d31313131e114000041ca9bcdf3087675bf11776860b515fd4ced2dfb28cd3b3338')
# packet correct
# crc fail
# packet correct
# crc fail
# packet correct
# Packet found with 1 bit errors. Bits correct was 215
# ('truth:  ', '999999991acffc1d23232323e71400005e491172ebfdcb08bc95d8')
# ('decoded:', '999999991acffc1d23232323e71400005e491172ebfdcb08bc9598')
# Packet found with 56 bit errors. Bits correct was 288
# ('truth:  ', '999999991acffc1d33333333e8140000f461215288c782766a8a2428e0746193e86d59f2aee66ebd842350')
# ('decoded:', '999999991acffc1d33333333e8140000f461215288c782766a8a262c623239997e340c5bf77337d4e2b90a')
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# Packet found with 7 bit errors. Bits correct was 209
# ('truth:  ', '999999991acffc1d23232323f01400007826dfbf0191591c977660')
# ('decoded:', '')
# packet correct
# packet correct
# No packet found, adding 216 bit errors
# packet correct
# packet correct
# No packet found, adding 176 bit errors
# packet correct
# packet correct
# crc fail
# Packet found with 3 bit errors. Bits correct was 277
# ('truth:  ', '999999991acffc1d2b2b2b2bfb140000073df754e7aa1e73001f4d7514034eeed04fb1')
# ('decoded:', '999999991acffc1d2b2b2b2bfb140000073df754e7aa1e73001f4d7514034e6ed04f99')
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# Packet found with 2 bit errors. Bits correct was 270
# ('truth:  ', '999999991acffc1d2a2a2a2a20150000979881383957507cee1d80628a353648224b')
# ('decoded:', '999999991acffc1d2a2a2a2a20150000979881383957507cee1d80628a373648264b')
# packet correct
# Packet found with 19 bit errors. Bits correct was 293
# ('truth:  ', '999999991acffc1d2f2f2f2f221500001c6f7d106bd5eea134b0e8100983a5b21b0e7fc62d77da')
# ('decoded:', '...')
# packet correct
# packet correct
# Packet found with 3 bit errors. Bits correct was 229
# ('truth:  ', '999999991acffc1d25252525261500000a8084412ecbc60e9a029f8021')
# ('decoded:', '999999991acffc1d25252525261500000a8084412ecbc60e9a029b8063')
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# Packet found with 2 bit errors. Bits correct was 326
# ('truth:  ', '999999991acffc1d313131313b1500008bf9b085d2fc45583d0fa76852b99f31717a72f014ddcf2416')
# ('decoded:', '999999991acffc1d313131313b1500008bf9b085d2fc45583d0fa76852b99f31717a72f014cccf2416')
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# Packet found with 5 bit errors. Bits correct was 267
# ('truth:  ', '999999991acffc1d2a2a2a2a501500000b38be53dd92cb56e86c2e6259b719fc1748')
# ('decoded:', '999999991acffc1d2a2a2a2a501500000b38be53dd92cb56e86c266259b319dc134c')
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# No packet found, adding 200 bit errors
# packet correct
# crc fail
# crc fail
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# crc fail
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# Packet found with 53 bit errors. Bits correct was 251
# ('truth:  ', '999999991acffc1d2e2e2e2e7c150000b2e64ea7d1948ec0c13d14032c8f66dd266785779883')
# ('decoded:', '999999991acffc1d2e2e2e2e7c150000b2e64ea7d994cec0c99d82a9b6e53344b331e011cee9')
# Packet found with 24 bit errors. Bits correct was 312
# ('truth:  ', '999999991acffc1d323232327d1500006aeb9c4519a5c9734e12265a70e7eef7d46e5ac3de008ce98694')
# ('decoded:', '999999991acffc1d323232327d1500006aeb9c4519a5c9734e12265a70e76e77d6664ec1ce28c66ce3c2')
# packet correct
# crc fail
# Packet found with 10 bit errors. Bits correct was 326
# ('truth:  ', '999999991acffc1d323232328015000010259031450d9013e37484c78650112b2c634174c7b79ae8bc10')
# ('decoded:', '999999991acffc1d323232328015000010259031450d9013e37484c78650113b2c634176c7b19aecdc88')
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# Packet found with 21 bit errors. Bits correct was 315
# ('truth:  ', '999999991acffc1d323232328f1500004635f3690250ac54f61313c40d462f0a921290a4b7b11edb4dac')
# ('decoded:', '999999991acffc1d323232328f1500004635f3690250ac54f61313c40d462f0a931398e6b1998ecd24e6')
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# Packet found with 1 bit errors. Bits correct was 223
# ('truth:  ', '999999991acffc1d24242424951500004190a2d25db1e7c7b63a4675')
# ('decoded:', '999999991acffc1d24242424951500004190a2d25db1e7c7b63a6675')
# packet correct
# Packet found with 14 bit errors. Bits correct was 274
# ('truth:  ', '999999991acffc1d2c2c2c2c97150000b4c4824401637110828f742f2429253cc9cb3f00')
# ('decoded:', '999999991acffc1d2c2c2c2c97150000b4c4824401637110828f742f2629313cccc995aa')
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# crc fail
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# packet correct
# Packet found with 1 bit errors. Bits correct was 335
# ('truth:  ', '999999991acffc1d32323232ad150000f352c863e6b1121930533134daab6f05f5f00be2a7eeea6d36fb')
# ('decoded:', '999999991acffc1d32323232ad150000f352c863e6b1121930533134daab6f05f5f00be2a7eeea6d367b')
# crc fail
# packet correct
# Packet found with 23 bit errors. Bits correct was 345
# ('truth:  ', '999999991acffc1d36363636b01500008e13afdf5767b08941d5cf443934eb48d626e56a0ed8aab5d05ca201cc09')
# ('decoded:', '999999991acffc1d36363636b01500008e13afdf5767b08941d5cf443934eb48d626656a0eccebb1c84cf32866ac')
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# packet correct
# crc fail
# crc fail
# packet correct
# crc fail
# Packet found with 14 bit errors. Bits correct was 234
# ('truth:  ', '999999991acffc1d27272727c0150000d17a225008e22daa4602f96eef85f6')
# ('decoded:', '999999991acffc1d27272727c0150000d17a225008e22daa4646f9ccce9fac')
# found 5300 packets out of total 5570
# Bit error rate was 0.17403530733, correct bits: 1488580 total bits 1802232

# %%
sanity_checks = [ {"ind":i, "packet":p, "packet_len":len(p)} for i,p in enumerate(decoded_packets)]
packet_counters = np.array( [struct.unpack("<H",p[12:14])[0] for p in decoded_packets])


print(packet_counters)
print(np.diff(packet_counters))

for s in sanity_checks:
    p=s["packet"]
    packet_lens = np.array(struct.unpack("<BBBB",p[8:12]), dtype=np.uint8)
    unique_vals, unique_counts = np.unique(packet_lens, return_counts=True)
    
    if np.any( unique_vals==len(p) ):
        s["packet_len_is_sane"]=True
        
    #s["packet_count"]
# Out:
# []
# []

# %%
# first pass, remove all packets that matched perfectly
matched_truth_packets = []
missing_truth_packets = []

for tp in truth_packets:
    ind, matched = next( ((i, p) for i,p in enumerate(decoded_packets) if p == tp), (-1, None))
    
    if ind>=0:
        matched_truth_packets.append(tp)
        del decoded_packets[ind] 
    else:
        missing_truth_packets.append(tp)

print("found {} matches".format(len(matched_truth_packets)))
print("missing {} packets".format(len(missing_truth_packets)))
print("{} decoded packets remain".format(len(decoded_packets)))
# Out:
# found 0 matches
# missing 5589 packets
# 0 decoded packets remain

# %%
max_errors_per_packet = 8

dp_ind = 0

matched_truth_packets = {}
missing_truth_packets = {}
matched_decoded_packets = {}
missing_decoded_packets = {}

match_scores = np.array((len(truth_packets), len(decoded_packets)))

# for each truth packet, store the index to the matching decoded packet
truth_decoded_inds = np.array( -1*ones(len(truth_packets),))

for tp_ind, tp in enumerate(truth_packets):
    ind, matched = next( ((i, p) for i,p in enumerate(decoded_packets) if p == tp), (-1, None))
    
    # the first packet with a perfect match wins
    if ind>=0:
        truth_decoded_inds[tp_ind] = ind

        
# now compute all the bit errors         
for i in len(truth_packets):
    for j in len(decoded_packets):
        
        # check if packets have the same length
        if len(tp) > len(dp):
            tp_check = tp[:len(dp)]
            dp_check = dp
            
        elif len(dp) > len(tp):
            tp_check = tp
            dp_check = dp[:len(tp)]
        else:
            tp_check = tp
            dp_check = dp
    
        # take xor of now matching length packets to determine match score
        packet_diff = tp_check ^ dp_check
        bit_errors = bin(packet_diff).count("1")
        
        match_scores[i,j] = bit_errors

for i in len(truth_packets):        
    
    last_match = -1
    
    # skip any packets with a perfect match
    if truth_decoded_inds[i]>=0:
        pass
    else:
        scores = match_scores[i,last_match+1:]
        print(scores)
        
        best_ind = np.argmin(scores)

# %%
    ind, matched = next( ((i, p) for i,p in enumerate(decoded_packets) if p == tp), (-1, None))
    
    if ind>=0:
        matched_truth_packets.append(tp)
        del decoded_packets[ind] 
    else:
        missing_truth_packets.append(tp)

for tp_ind, tp in enumerate(truth_packets):
    sync = False
    
    while sync == False:
        # try to sync to current packet. Find current difference in packet bytes.
        # start by getting a copy of dp
        dp = decoded_packets[dp_ind]

        # check if packets have the same length
        if len(tp) > len(dp):
            tp_check = tp[:len(dp)]
            dp_check = dp
        elif len(dp) > len(tp):
            tp_check = tp
            dp_check = dp[:len(tp)]
        else:
            tp_check = tp
            dp_check = dp


        

        if bit_errors > max_errors_per_packet:
            # no sync
            
    
    pos = decoded_bytes.find(tp)
    if pos >=0:
        matched_packets.append(tp)
        decoded_bytes[pos:pos+len(tp)] = b''
    else:
        missing_packets =

# %%
a = 0x999999991acffc1d222222220000164f65bf68c800604d8dc3c4195384ef9697db59
b = 0x999999991acffc1d222222220000164f65bf68c800604d8dc3c4195384ef9697db50

abdiff = a^b
print(bin(abdiff).count("1"))

# %%
truth_name = "/home/cpomeroy/Projects/DARPA/hurdle1/truth_packets.bin"

# %%
256/4

# %%
260/4

# %%
(256-PACKET_HEADER_LEN-FRAME_HEADER_LEN)/4.0

# %%
57 + PACKET_HEADER_LEN - 2

# %%
69*4

# %%
PACKET_HEADER_LEN

# %%
FRAME_HEADER_LEN

# %%
255-14

# %%
256/4.0
